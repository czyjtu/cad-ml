# %%
from pathlib import Path
from skimage import data, img_as_float
from skimage.segmentation import chan_vese

import numpy as np
import matplotlib.pyplot as plt

import coronaryx as cx
import coronaryx.functions as cxf
import coronaryx.algorithms as cxa
import coronaryx.plot as cxp

DATA_DIR = Path().absolute().parent / "data"

# %%
dataset = cx.read_dataset(DATA_DIR)
cxp.plot_dataset(dataset)

# %% [markdown]
# ## TODO
# For a given scan image, run with a given window along a center-line, perform a local segmentation, and append result mask to the final global segmentation.
# - Experiment with parameters (*init_level_set*, ...)

# %%
item = dataset[15]
cx.plot_scan(item)

# %%
mask = cxa.chan_vese_mask(item, 10)
plt.rcParams["figure.figsize"] = (8, 8)
plt.imshow(mask)

# %%
cx.plot_scan(item)
